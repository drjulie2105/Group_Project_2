# %%
import pandas as pd 
import os

# %%
file_to_load = "..\data\Turnout_Rates.csv"
turnout_df = pd.read_csv(file_to_load)
turnout_df
# Out:
#      Year  ICPSR State Code  Alphanumeric State Code     Unnamed: 3  \
# 0    2014                 0                        0  United States
# 1    2014                41                        1        Alabama
# 2    2014                81                        2         Alaska
# 3    2014                61                        3        Arizona
# 4    2014                42                        4       Arkansas
# ..    ...               ...                      ...            ...
# 931  1980                40                       47       Virginia
# 932  1980                73                       48     Washington
# 933  1980                56                       49  West Virginia
# 934  1980                25                       50      Wisconsin
# 935  1980                68                       51        Wyoming
#
#     VEP Total Ballots Counted VEP Highest Office VAP Highest Office  \
# 0                       36.7%              36.0%              33.2%
# ...

# %%
turnout_df = turnout_df.drop(['ICPSR State Code','Alphanumeric State Code','Highest Office','% Non-citizen','Prison','Probation','Parole','Total Ineligible Felon','Overseas Eligible','VEP Highest Office','Voting-Age Population (VAP)','VAP Highest Office'],axis=1)
turnout_df = turnout_df.rename(columns={'Unnamed: 3':'State'})

# %%
turnout_2000 = turnout_df[turnout_df.Year == 2000]
turnout_2000 = turnout_2000#rename Unnamed: 3 rename VEP Total Ballots Counted Rename Total Ballots Counted and Voting-Eligible Population (VEP) and drop VAP Highest Office
#do the above line from all years
turnout_2000
# Out:
#      Year                 State VEP Total Ballots Counted  \
# 364  2000         United States                     55.3%
# 365  2000               Alabama                       NaN
# 366  2000                Alaska                     68.7%
# 367  2000               Arizona                     46.4%
# 368  2000              Arkansas                       NaN
# 369  2000            California                     56.6%
# 370  2000              Colorado                       NaN
# 371  2000           Connecticut                     62.5%
# 372  2000              Delaware                       NaN
# 373  2000  District of Columbia                       NaN
# 374  2000               Florida                     57.5%
# 375  2000               Georgia                     47.6%
# 376  2000                Hawaii                     44.6%
# 377  2000                 Idaho                     58.9%
# 378  2000              Illinois                     58.5%
# ...

# %%
turnout_2004 = turnout_df[turnout_df.Year == 2004]
#turnout_2004

# %%
turnout_2008 = turnout_df[turnout_df.Year == 2008]

# %%
turnout_2012 = turnout_df[turnout_df.Year == 2012]

# %%
file_to_load = "..\data\Turnout_Rates_2016.csv"
turnout_2016 = pd.read_csv(file_to_load)
turnout_2016
# Out:
# 5
# Illinois                                                             9,866,799
# Indiana                                                              5,063,393
# Iowa                                                                 2,406,915
# Kansas                                                               2,192,423
# Kentucky                                                             3,430,652
# Louisiana                                                            3,571,652
# Maine                                                                1,078,037
# Maryland                                                             4,670,900
# Massachusetts                                                        5,442,458
# Michigan                                                             7,744,567
# Minnesota                                                            4,240,423
# Mississippi                                                          2,268,089
# ...

# %%
turnout_2016 = turnout_2016.drop(['State Results Website','Highest Office','% Non-citizen','Prison','Probation','Parole','Total Ineligible Felon','Overseas Eligible','VEP Highest Office','Voting-Age Population (VAP)','Status','State Abv'],axis=1)

# %%
# Out:
#                                                 43.2%
# Idaho                                                                  60.9%
# Illinois                                                               63.1%
# Indiana                                                                57.9%
# Iowa                                                                   69.1%
# Kansas                                                                 59.7%
# Kentucky                                                               59.6%
# Louisiana                                                              60.6%
# Maine                                                                  72.9%
# Maryland                                                               67.0%
# Massachusetts                                                          68.3%
# Michigan                                                               65.7%
# ...

# %%
turnout_2016 = turnout_2016[:-1]
turnout_2016['year'] = 2016
turnout_2016 = turnout_2016.drop(columns=("VAP Highest Office"))
turnout_2016
# Out:
#                      VEP Total Ballots Counted  \
# United States                            60.1%
# Alabama                                  59.1%
# Alaska                                   61.5%
# Arizona                                  56.1%
# Arkansas                                 53.2%
# California                               58.2%
# Colorado                                 71.9%
# Connecticut                              64.9%
# Delaware                                 64.4%
# District of Columbia                     60.7%
# Florida                                  65.6%
# Georgia                                  59.8%
# Hawaii                                   43.2%
# Idaho                                    60.9%
# Illinois                                 63.1%
# Indiana                                  57.9%
# Iowa                                     69.1%
# Kansas                                   59.7%
# Kentucky                                 59.6%
# ...
